# %%
import os
import requests
import xml.etree.ElementTree as ET
from dotenv import load_dotenv

# %%
import numpy as np 
import pandas as pd
import os

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# Load environment variables from the .env file
load_dotenv()

# Get the API key from the environment variable
api_key = os.getenv("DATA_SEOUL_APIKEY")

# %%
# Define the range of months and years
years = [2023, 2024]
months = list(range(1, 13))  # January to December

# Initialize an empty list to hold the data
all_data = []

# Function to fetch and parse data for a given year and month
def fetch_data(year, month):
    # Format the month to ensure two digits
    month_str = f"{month:02d}"
    date_str = f"{year}{month_str}"
    print(date_str)
    url = f"http://openapi.seoul.go.kr:8088/{api_key}/xml/CardBusTimeNew/1/1000/{date_str}/"
    
    res = requests.get(url)
    
    if res.status_code == 200:
        root = ET.fromstring(res.content)
        data = []
        for item in root.findall('.//row'):
            record = {child.tag: child.text for child in item}
            data.append(record)
        return data
    else:
        print(f"Error: Unable to fetch data for {date_str}. Status code: {res.status_code}")
        return []

# %%
# Loop through each year and month to fetch the data
for year in years:
    for month in months:
        if year == 2023 or (year == 2024 and month in range(1, 6)):
            data = fetch_data(year, month)
            all_data.extend(data)

# Convert the list of all records to a DataFrame
df = pd.DataFrame(all_data)
# Out:
# 202301
# 202302
# 202303
# 202304
# 202305
# 202306
# 202307
# 202308
# 202309
# 202310
# 202311
# 202312
# 202401
# 202402
# 202403
# 202404
# 202405

# %%
df
# Out:
#       USE_MON BUS_ROUTE_NO    BUS_ROUTE_NM STND_BSST_ID BSST_ARS_NO  \
# 0      202301          100  100번(하계동~용산구청)    110000327       11428
# 1      202301          100  100번(하계동~용산구청)    110000335       11436
# 2      202301          100  100번(하계동~용산구청)    107000011       08101
# 3      202301          100  100번(하계동~용산구청)    107000012       08102
# 4      202301          100  100번(하계동~용산구청)    107000013       08103
# ...       ...          ...             ...          ...         ...
# 15995  202404          143    143번(정릉~개포동)    990074870           ~
# 15996  202404          143    143번(정릉~개포동)    107000005       08005
# 15997  202404          143    143번(정릉~개포동)    100000133       01229
# 15998  202404          143    143번(정릉~개포동)    107000010       08010
# 15999  202404          143    143번(정릉~개포동)    107000008       08008
#
#                     BUS_STA_NM MIDNIGHT_RIDE_NUM MIDNIGHT_ALIGHT_NUM  \
# 0                한성여객종점(00001)                 0                   2
# 1              하계1동주민센터(00010)                 0                   0
# 2                숭곡초교입구(00100)               149                  98
# 3                  창문여고(00101)               167                 220
# 4                  동방고개(00102)                11                 151
# ...                        ...               ...                 ...
# 15995       대진여객차고지(가상)(00001)                 0                   4
# 15996     미아리고개.미아리예술극장(00010)                 0                   0
# 15997  혜화역.동성중고(장면총리가옥)(00100)               412                 265
# 15998  삼선교.한성대학교.조소앙활동터(00101)               325                 462
# 15999      돈암사거리.성신여대입구(00102)               925                 663
#
#       ONE_RIDE_NUM ONE_ALIGHT_NUM  ... TWENTY_ALIGHT_NUM TWENTY_ONE_RIDE_NUM  \
# 0                0              2  ...                 0                   5
# 1                0              0  ...                36                 135
# 2               16             24  ...               243                 247
# 3               27             33  ...               425                 300
# 4                6             32  ...               176                  45
# ...            ...            ...  ...               ...                 ...
# 15995            0              0  ...               105                 236
# 15996            0              0  ...               468                 119
# 15997           86             31  ...               365                 854
# 15998          125             75  ...               912                 578
# 15999          288            168  ...              1044                1141
#
#       TWENTY_ONE_ALIGHT_NUM TWENTY_TWO_RIDE_NUM TWENTY_TWO_ALIGHT_NUM  \
# 0                         2                   3                     2
# 1                        29                 150                    37
# 2                       233                 158                   308
# 3                       491                 282                   503
# 4                       173                  28                   204
# ...                     ...                 ...                   ...
# 15995                   153                 152                   127
# 15996                   355                  40                   145
# 15997                   341                 856                   354
# 15998                   875                 613                   845
# 15999                  1091                1201                  1108
#
#       TWENTY_THREE_RIDE_NUM TWENTY_THREE_ALIGHT_NUM MNTN_TYP_CD MNTN_TYP_NM  \
# 0                         0                       0         010      서울간선버스
# 1                         0                       0         010      서울간선버스
# 2                       135                     192         010      서울간선버스
# 3                       196                     303         010      서울간선버스
# 4                        21                     164         010      서울간선버스
# ...                     ...                     ...         ...         ...
# 15995                    57                      60         010      서울간선버스
# 15996                     0                       0         010      서울간선버스
# 15997                   425                     272         010      서울간선버스
# 15998                   300                     579         010      서울간선버스
# 15999                   719                     636         010      서울간선버스
#
#         WORK_DT
# 0      20230203
# 1      20230203
# 2      20230203
# 3      20230203
# 4      20230203
# ...         ...
# 15995  20240503
# 15996  20240503
# 15997  20240503
# 15998  20240503
# 15999  20240503
#
# [16000 rows x 57 columns]

# %%
df.columns
# Out:
# Index([], dtype='object')

# %%
# 사용년월 열의 고유한 값들을 모음
unique_usage_months = df['USE_MON'].unique()

# 고유한 사용년월 출력
print(unique_usage_months)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'USE_MON'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22976\2834287764.py in <module>
#       1 # 사용년월 열의 고유한 값들을 모음
# ----> 2 unique_usage_months = df['USE_MON'].unique()
#       3
#       4 # 고유한 사용년월 출력
#       5 print(unique_usage_months)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'USE_MON'

# %%
# 사용년월 열의 고유한 값들을 모음
bus_route_no = df['BUS_ROUTE_NO'].unique()

# 고유한 사용년월 출력
print(bus_route_no)

# %%
# 사용년월 열의 고유한 값들을 모음
bus_route_no = df['BUS_ROUTE_NM'].unique()

# 고유한 사용년월 출력
print(bus_route_no)

# %%
# 사용년월 열의 고유한 값들을 모음
unique_usage_months = df = (df['USE_MON'] == 202404)

# 고유한 사용년월 출력
print(unique_usage_months)
